# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# %%
cake=pd.read_excel(r"C:\Users\Lenovo\Desktop\ML agribusiness\Vorlesung_mit_Übung_Machine_Learning_in_Food_Economics_and_Agribusiness\Discrete_Cake.xls")
cake.describe
# Out:
# <bound method NDFrame.describe of       id  size  income  age  gender  marriage  edu  children  bid1  wtp1  ...  \
# 0    326     1       3   52       0       1.0    3         0   2.5     0  ...
# 1    167     1       4   65       1       1.0    4         1   1.6     0  ...
# 2    170     2       8   66       1       1.0    5         0   1.6     0  ...
# 3    314     1       2   18       0       2.0    4         0   1.0     1  ...
# 4    712     1       4   51       0       1.0    4         1   1.0     1  ...
# ..   ...   ...     ...  ...     ...       ...  ...       ...   ...   ...  ...
# 295  848     2       6   73       0       1.0    1         0   1.0     0  ...
# 296  352     1       5   30       0       2.0    5         0   2.5     0  ...
# 297  173     2       3   41       0       1.0    3         1   1.6     1  ...
# 298  816     2       3   23       0       2.0    5         0   2.5     1  ...
# 299  159     2       6   33       0       2.0    3         0   1.6     1  ...
#
#      wtp2  wtpopen  price  openbid  cake_no  brand Transport  \
# 0       0      0.0    1.0        0        1      A         1
# 1       0      1.0    1.0        0        2      A         2
# 2       0      0.0    1.0        0        6      B         2
# 3       0      1.0    1.0        1        1      B         0
# 4       0      1.0    1.0        1        2      C         2
# ..    ...      ...    ...      ...      ...    ...       ...
# 295     0      0.0    3.0        0        3      E         3
# 296     1      2.0    4.0        2        4      E         3
# 297     1      3.0    5.0        3        1      D         1
# 298     1      5.0    4.0        5        2      A         1
# 299     1      5.0    5.0        5        4      B         3
#
#      Service_satisfaction  environment_satisfaction  Safety_concern
# 0                       2                         3               2
# 1                       3                         3               3
# 2                       3                         3               3
# 3                       1                         1               1
# 4                       3                         3               3
# ..                    ...                       ...             ...
# 295                     4                         5               4
# 296                     3                         5               4
# 297                     2                         3               2
# 298                     2                         3               2
# 299                     4                         5               4
#
# [300 rows x 21 columns]>

# %%
cake_clean=cake.dropna()
cake_clean
# Out:
#       id  size  income  age  gender  marriage  edu  children  bid1  wtp1  ...  \
# 0    326     1       3   52       0       1.0    3         0   2.5     0  ...
# 1    167     1       4   65       1       1.0    4         1   1.6     0  ...
# 2    170     2       8   66       1       1.0    5         0   1.6     0  ...
# 3    314     1       2   18       0       2.0    4         0   1.0     1  ...
# 4    712     1       4   51       0       1.0    4         1   1.0     1  ...
# ..   ...   ...     ...  ...     ...       ...  ...       ...   ...   ...  ...
# 295  848     2       6   73       0       1.0    1         0   1.0     0  ...
# 296  352     1       5   30       0       2.0    5         0   2.5     0  ...
# 297  173     2       3   41       0       1.0    3         1   1.6     1  ...
# 298  816     2       3   23       0       2.0    5         0   2.5     1  ...
# 299  159     2       6   33       0       2.0    3         0   1.6     1  ...
#
#      wtp2  wtpopen  price  openbid  cake_no  brand Transport  \
# 0       0      0.0    1.0        0        1      A         1
# 1       0      1.0    1.0        0        2      A         2
# 2       0      0.0    1.0        0        6      B         2
# 3       0      1.0    1.0        1        1      B         0
# 4       0      1.0    1.0        1        2      C         2
# ..    ...      ...    ...      ...      ...    ...       ...
# 295     0      0.0    3.0        0        3      E         3
# 296     1      2.0    4.0        2        4      E         3
# 297     1      3.0    5.0        3        1      D         1
# 298     1      5.0    4.0        5        2      A         1
# 299     1      5.0    5.0        5        4      B         3
#
#      Service_satisfaction  environment_satisfaction  Safety_concern
# 0                       2                         3               2
# 1                       3                         3               3
# 2                       3                         3               3
# 3                       1                         1               1
# 4                       3                         3               3
# ..                    ...                       ...             ...
# 295                     4                         5               4
# 296                     3                         5               4
# 297                     2                         3               2
# 298                     2                         3               2
# 299                     4                         5               4
#
# [295 rows x 21 columns]

# %%
# use data for training
x=cake_clean.iloc[:,1:9]  ##x variables are size	income	age	gender	marriage	edu	children
y=cake_clean['wtp1']  ##

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,RidgeCV,lasso_path,LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
##samle spit for training and tesing
x_train, x_test,y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=10)
##print dimension of train and test samples
print("the dimension of x_train is {}".format(x_train.shape))
print("the dimension of x_test is {}".format(x_test.shape))
# Out:
# the dimension of x_train is (206, 8)
# the dimension of x_test is (89, 8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
# train logit model
#from sklearn.linear_model import LogisticRegression
lr= LogisticRegression(penalty='l2',C=10,random_state=0) # penalty : 11= lasso. 12 = ridge
lr.fit(x_train,y_train)
# Out:
# c:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=10, random_state=0)

# %%
## test the model 
# generate evaluation metrics
print("Train_accuracy:",metrics.accuracy_score(y_train,lr.predict(x_train)))
print("Train_confusion matrix:",metrics.confusion_matrix(y_train,lr.predict(x_train)))
print("Train classification report:",metrics.classification_report(y_train,lr.predict(x_train)))

# generate evaluation matrix for test set 

print("Test_accuracy:",metrics.accuracy_score(y_test,lr.predict(x_test)))
print("Test_confusion matrix:",metrics.confusion_matrix(y_test,lr.predict(x_test)))
print("Test classification report:",metrics.classification_report(y_test,lr.predict(x_test)))
# Out:
# Train_accuracy: 0.8106796116504854
# Train_confusion matrix: [[  4  37]
#  [  2 163]]
# Train classification report:               precision    recall  f1-score   support
#
#            0       0.67      0.10      0.17        41
#            1       0.81      0.99      0.89       165
#
#     accuracy                           0.81       206
#    macro avg       0.74      0.54      0.53       206
# weighted avg       0.79      0.81      0.75       206
#
# Test_accuracy: 0.8314606741573034
# Test_confusion matrix: [[ 1 13]
#  [ 2 73]]
# Test classification report:               precision    recall  f1-score   support
#
#            0       0.33      0.07      0.12        14
#            1       0.85      0.97      0.91        75
#
#     accuracy                           0.83        89
#    macro avg       0.59      0.52      0.51        89
# weighted avg       0.77      0.83      0.78        89

# %%
# multiclass case

x=cake_clean.iloc[:,1:9]  ##x variables are size	income	age	gender	marriage	edu	children
y=cake_clean['brand']  ##

# %%
# convert y "brand" from character to number

import pandas as pd 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cake_clean['brand_num']=le.fit_transform(cake_clean.brand)
#y['brand_num']=le.fit_transform[y.brand]
print(cake_clean)
# Out:
#       id  size  income  age  gender  marriage  edu  children  bid1  wtp1  ...  \
# 0    326     1       3   52       0       1.0    3         0   2.5     0  ...
# 1    167     1       4   65       1       1.0    4         1   1.6     0  ...
# 2    170     2       8   66       1       1.0    5         0   1.6     0  ...
# 3    314     1       2   18       0       2.0    4         0   1.0     1  ...
# 4    712     1       4   51       0       1.0    4         1   1.0     1  ...
# ..   ...   ...     ...  ...     ...       ...  ...       ...   ...   ...  ...
# 295  848     2       6   73       0       1.0    1         0   1.0     0  ...
# 296  352     1       5   30       0       2.0    5         0   2.5     0  ...
# 297  173     2       3   41       0       1.0    3         1   1.6     1  ...
# 298  816     2       3   23       0       2.0    5         0   2.5     1  ...
# 299  159     2       6   33       0       2.0    3         0   1.6     1  ...
#
#      wtpopen  price  openbid  cake_no  brand  Transport Service_satisfaction  \
# 0        0.0    1.0        0        1      A          1                    2
# 1        1.0    1.0        0        2      A          2                    3
# 2        0.0    1.0        0        6      B          2                    3
# 3        1.0    1.0        1        1      B          0                    1
# 4        1.0    1.0        1        2      C          2                    3
# ..       ...    ...      ...      ...    ...        ...                  ...
# 295      0.0    3.0        0        3      E          3                    4
# 296      2.0    4.0        2        4      E          3                    3
# 297      3.0    5.0        3        1      D          1                    2
# 298      5.0    4.0        5        2      A          1                    2
# 299      5.0    5.0        5        4      B          3                    4
#
#      environment_satisfaction  Safety_concern  brand_num
# 0                           3               2          0
# 1                           3               3          0
# 2                           3               3          1
# 3                           1               1          1
# 4                           3               3          2
# ..                        ...             ...        ...
# 295                         5               4          4
# 296                         5               4          4
# 297                         3               2          3
# 298                         3               2          0
# 299                         5               4          1
#
# [295 rows x 22 columns]
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8328\1777337488.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cake_clean['brand_num']=le.fit_transform(cake_clean.brand)

# %%
y=cake_clean['brand_num']
x=cake_clean.iloc[:,1:9]
print('brand',np.unique(y))
# Out:
# brand [0 1 2 3 4]

# %%
# in practice we often normalize the data ( but not necessary) 
sc= standardScaler

# %%
#samle spit for training and tesing
x_train, x_test,y_train, y_test=train_test_split(x1,y,test_size=0.3,random_state=10)
##print dimension of train and test samples
print("the dimension of x_train is {}".format(x_train.shape))
print("the dimension of x_test is {}".format(x_test.shape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8328\2028970679.py in <module>
#       1 #samle spit for training and tesing
# ----> 2 x_train, x_test,y_train, y_test=train_test_split(x1,y,test_size=0.3,random_state=10)
#       3 ##print dimension of train and test samples
#       4 print("the dimension of x_train is {}".format(x_train.shape))
#       5 print("the dimension of x_test is {}".format(x_test.shape))
#
# NameError: name 'x1' is not defined

# %%
# do above by looking code given in studio

# %%
#pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.43.0-cp38-cp38-win_amd64.whl (447 kB)
#      ------------------------------------ 447.3/447.3 kB 229.3 kB/s eta 0:00:00
# Requirement already satisfied: packaging>20.9 in c:\users\lenovo\anaconda3\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (from shap) (2.0.3)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from shap) (1.10.1)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\lenovo\anaconda3\lib\site-packages (from shap) (4.64.0)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\lib\site-packages (from shap) (1.2.2)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from shap) (1.24.3)
# Requirement already satisfied: cloudpickle in c:\users\lenovo\anaconda3\lib\site-packages (from shap) (2.0.0)
# Collecting numba
#   Downloading numba-0.58.1-cp38-cp38-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.5)
# Collecting llvmlite<0.42,>=0.41.0dev0
#   Downloading llvmlite-0.41.1-cp38-cp38-win_amd64.whl (28.1 MB)
#      ---------------------------------------- 28.1/28.1 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in c:\users\lenovo\anaconda3\lib\site-packages (from numba->shap) (4.12.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata->numba->shap) (3.8.0)
# Installing collected packages: slicer, llvmlite, numba, shap
# Successfully installed llvmlite-0.41.1 numba-0.58.1 shap-0.43.0 slicer-0.0.7
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\anaconda3\lib\site-packages)

# %%
# how to open blackbox
# shapely value
import shap
explainer=shap.LinearExplainer(lr,x_train).shap_values(x_train)
shap.summary_plot(shap_values, x_train, plot_type="bar")

# positive and neg relationship of predictor with target 
shap.summary_plot=(x_train, )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8328\1007024419.py in <module>
#       3 import shap
#       4 explainer=shap.LinearExplainer(lr,x_train).shap_values(x_train)
# ----> 5 shap.summary_plot(shap_values, x_train, plot_type="bar")
#       6
#       7 # positive and neg relationship of predictor with target
#
# NameError: name 'shap_values' is not defined

# %%
#### Decision trees
